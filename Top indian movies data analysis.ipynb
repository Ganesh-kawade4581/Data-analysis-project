# %% [markdown]
# ## **Data visualisation of Top Indian movies**

# %% [markdown]
# ## **Objective**

# %% [markdown]
# the main objective of this project is to get information about top 250 indian movies according to their IMDB rating and also catagory of movies.

# %% [markdown]
# ## **Data Source**

# %% [markdown]
# https://www.kaggle.com/datasets/khushipitroda/top-250-indian-movies-imdb

# %% [markdown]
# ## **Import Library**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## **Import Data**

# %%
df=pd.read_csv('D:Indian_movies.csv')
df
# Out:
#      Unnamed: 0  Rank                          Movie Names  \
# 0             0     1  Ramayana: The Legend of Prince Rama
# 1             1     2           Rocketry: The Nambi Effect
# 2             2     3                              Nayakan
# 3             3     4                             Gol Maal
# 4             4     5                           Anbe Sivam
# ..          ...   ...                                  ...
# 245         245   246                           Kai Po Che
# 246         246   247                       Poove Unakkaga
# 247         247   248                                Raazi
# 248         248   249                          Dasvidaniya
# 249         249   250                                  Dia
#
#                                                  Links  Rating  Year  \
# 0    https://www.imdb.com//title/tt0259534/?ref_=fe...     9.2  1993
# 1    https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# ...

# %% [markdown]
# ## **Describe Data**

# %%
df.describe()
# Out:
#        Unnamed: 0        Rank      Rating        Year
# count  250.000000  250.000000  250.000000   250.00000
# mean   124.500000  125.500000    8.182000  2007.97600
# std     72.312977   72.312977    0.263198    14.66546
# min      0.000000    1.000000    7.700000  1955.00000
# 25%     62.250000   63.250000    8.000000  2003.00000
# 50%    124.500000  125.500000    8.100000  2013.00000
# 75%    186.750000  187.750000    8.300000  2018.00000
# max    249.000000  250.000000    9.200000  2023.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         250 non-null    int64
#  1   Rank               250 non-null    int64
#  2   Movie Names        250 non-null    object
#  3   Links              250 non-null    object
#  4   Rating             250 non-null    float64
#  5   Year               250 non-null    int64
#  6   Duration_of_movie  250 non-null    object
#  7   Genere             250 non-null    object
#  8   Description        250 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 17.7+ KB

# %%
df.nunique()
# Out:
# Unnamed: 0           250
# Rank                 250
# Movie Names          248
# Links                250
# Rating                15
# Year                  50
# Duration_of_movie     48
# Genere                68
# Description          250
# dtype: int64

# %% [markdown]
# ## **Data Visualization**

# %%
sns.pairplot(df)

# %%
sns.countplot(x='Rating',data=df)
# Out:
# <Axes: xlabel='Rating', ylabel='count'>

# %% [markdown]
# ## **Data Preprocessing**

# %%
Top_Movies=df[df['Year']==2022]
Top_Movies
# Out:
#      Unnamed: 0  Rank                 Movie Names  \
# 1             1     2  Rocketry: The Nambi Effect
# 5             5     6                 777 Charlie
# 24           24    25                  Sita Ramam
# 60           60    61                      Vikram
# 85           85    86                  Drishyam 2
# 95           95    96              Jana Gana Mana
# 116         116   117          Kaun Pravin Tambe?
# 130         130   131                     Kantara
# 148         148   149            K.G.F: Chapter 2
# 169         169   170                       Major
# 186         186   187                       Gargi
# 194         194   195                    Hridayam
# 202         202   203                  Love Today
# 220         220   221                         RRR
#
#                                                  Links  Rating  Year  \
# 1    https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# ...

# %%
df[df['Year']==2022]
# Out:
#      Unnamed: 0  Rank                 Movie Names  \
# 1             1     2  Rocketry: The Nambi Effect
# 5             5     6                 777 Charlie
# 24           24    25                  Sita Ramam
# 60           60    61                      Vikram
# 85           85    86                  Drishyam 2
# 95           95    96              Jana Gana Mana
# 116         116   117          Kaun Pravin Tambe?
# 130         130   131                     Kantara
# 148         148   149            K.G.F: Chapter 2
# 169         169   170                       Major
# 186         186   187                       Gargi
# 194         194   195                    Hridayam
# 202         202   203                  Love Today
# 220         220   221                         RRR
#
#                                                  Links  Rating  Year  \
# 1    https://www.imdb.com//title/tt9263550/?ref_=fe...     8.7  2022
# ...

# %% [markdown]
# ## **Modeling**

# %%
sns.countplot(x='Year',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='count'>

# %% [markdown]
# ## **Evaluation**

# %%
df['Genere'].value_counts().nlargest(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Genere'>

# %%
df['Rating'].value_counts().nlargest(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Rating'>

# %% [markdown]
# ## **Explaination**

# %% [markdown]
# The "Top 250 Indian Movies" dataset comprises information on the highest-rated Indian movies according to user ratings on various platforms. This dataset contains 250 unique Indian movies that have garnered critical acclaim and popularity among viewers. Each movie is associated with essential details, including its rank, title, release year, duration, genre, IMDb rating, and a brief description.
# Above visualisation shows that over the dacade most liked movies was action and crime drama with highest visulisation and popularity over the years.
